# %% [markdown]
# <a href="https://colab.research.google.com/github/gredy/2021Z-DataVisualizationTechniques/blob/master/cebollitas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

datos_ceballitas = pd.read_csv("/var/colab/cebollitas.csv")
print(datos_ceballitas.head())

# %%
datos_ceballitas.info()

# %%
print(datos_ceballitas.isnull().sum())

# %%
datos_preparados = pd.get_dummies(datos_ceballitas, columns=["equipo_local", "equipo_visitante"])

# %%
datos_preparados = datos_preparados.drop_duplicates()

# %%
datos_ceballitas["fecha_partido"] = pd.to_datetime(datos_ceballitas["fecha_partido"], errors='coerce')

# %%
print(datos_preparados.info())
